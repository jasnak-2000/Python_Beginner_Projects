# %%
from tkinter import *

# %%
from tkinter.ttk import *

# %%
window = Tk()

window.title('Quiz Maker')

window.geometry('600x600')


q1_var = IntVar()
q2_var = IntVar()
q3_var = IntVar()
q4_var = IntVar()



# Question 1

lbl = Label(window, text ='1. Which is the capital of france ?')

lbl.place(x=10, y=10)




rad1 = Radiobutton(window,text='Berlin', value='A', variable = q1_var)

rad2 = Radiobutton(window,text='Madrid', value='B',variable = q1_var)

rad3 = Radiobutton(window,text='Paris', value='C',variable = q1_var)

rad4 = Radiobutton(window,text='Rom', value='D',variable = q1_var)

rad1.place(x=10, y=30)

rad2.place(x=10, y=50)

rad3.place(x=10, y=70)

rad4.place(x=10, y=90)


# question 2


lbl1 = Label(window, text ='2. Which is the largest mammal on Earth?')

lbl1.place(x=10, y=110)

rad5 = Radiobutton(window,text='African Eliphent', value='A', variable = q2_var)

rad6 = Radiobutton(window,text='Blue Whale', value='B', variable = q2_var)

rad7 = Radiobutton(window,text='Giraffe', value='C', variable = q2_var)

rad8 = Radiobutton(window,text='Great White Shark', value='D', variable = q2_var)

rad5.place(x=10, y=130)

rad6.place(x=10, y=150)

rad7.place(x=10, y=170)

rad8.place(x=10, y=190)


# Question 3


lbl2 = Label(window, text ='3. What is the chemical symbol for water?')

lbl2.place(x=10, y=210)

rad9 = Radiobutton(window,text='Co2', value='A', variable = q3_var)

rad10 = Radiobutton(window,text='O2', value='B', variable = q3_var)

rad11 = Radiobutton(window,text='H2O', value='C',variable = q3_var)

rad12 = Radiobutton(window,text='NaCl', value='D',variable = q3_var)

rad9.place(x=10, y=230)

rad10.place(x=10, y=250)

rad11.place(x=10, y=270)

rad12.place(x=10, y=290)


# question 4


lbl3 = Label(window, text ='''4. Who wrote "Romeo and Juliet"?''')

lbl3.place(x=10, y=310)

rad13 = Radiobutton(window,text='Charles Dickens', value='A', variable = q4_var)

rad14 = Radiobutton(window,text='William Shakespeare', value='B',variable = q4_var)

rad15 = Radiobutton(window,text='Mark Twain', value='C',variable = q4_var)

rad16 = Radiobutton(window,text='NaCl', value='D',variable = q4_var)

rad13.place(x=10, y=330)

rad14.place(x=10, y=350)

rad15.place(x=10, y=370)

rad16.place(x=10, y=390)


# click bButton


btn = Button( window, text='Submit')
btn.place (x=250, y=500)

















window.mainloop()
